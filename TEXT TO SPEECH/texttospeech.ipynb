# %%
# !pip install gTTS
# Out:
# ...
# WARNING: Ignoring invalid distribution -illow (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\mahfooz alam\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\mahfooz alam\anaconda3\lib\site-packages)

# %%
from gtts import gTTS

text_to_say = "This is a sample piece of text read by GTTS."

language = "en"

gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)

gtts_object.save("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\gtts.wav")

from IPython.display import Audio

Audio("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\gtts.wav")

french_text = "इनमें समय लगता है और मेहनत भी करनी पड़ेती है"

french_language = "en"

french_gtts_object = gTTS(text = french_text,
                          lang = french_language,
                          slow = True)

french_gtts_object.save("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\french.wav")

Audio("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\french.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS

text_to_say = "This is a sample piece of text read by GTTS."

language = "en"

gtts_object = gTTS(text = text_to_say,
                  lang = language,
                  slow = False)

gtts_object.save("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\gtts.wav")

from IPython.display import Audio

Audio("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\gtts.wav")

french_text = "this A computer takes up the responsibility and processes the output in no time, hence making our life easier. It collects the data, processes it and then provides the final result to us within a very short time. People in this day and age have become so reliant on computers that they cannot imagine life without them simple text?"

french_language = "en"

french_gtts_object = gTTS(text = french_text,
                          lang = french_language,
                          slow = True)

french_gtts_object.save("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\french.wav")

Audio("C:\\Users\\MAHFOOZ ALAM\\Desktop\\MINOR PROJECT\\Only for saving tasks\\french.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
